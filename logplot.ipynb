# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x): 
    return x**2

# %%
x=np.linspace(1, 1000, 100)
y=f(x)
plt.plot(x, y)

# %%
plt.loglog(x, y)

# %%
x2=np.log10(x)
y2=np.log10(y)
plt.plot(x2, y2)
